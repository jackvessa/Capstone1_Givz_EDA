# %%
# Imports
# %matplotlib inline

import os
import numpy as np
import pandas as pd
import numpy.random as rand
from itertools import islice
from sklearn.ensemble import (GradientBoostingRegressor, 
                              GradientBoostingClassifier, 
                              AdaBoostClassifier,
                              RandomForestClassifier)
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.svm import SVC
import math
import sklearn.datasets as datasets
# import sklearn.cross_validation as cv
import sklearn.model_selection as cv
from sklearn.ensemble.partial_dependence import partial_dependence, plot_partial_dependence
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import log_loss, make_scorer, confusion_matrix
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.datasets import load_breast_cancer, load_iris
from sklearn.linear_model import LogisticRegression

plt.style.use('ggplot')

from pylab import rcParams
rcParams['figure.figsize'] = (12, 8)
# from IPython.display import HTML

# %%
def score_matrix(obj):
    name = str(obj.__class__).split(".")[-1][:-2]
    score = obj.score(X_test,y_test)
    y_pred = obj.predict(X_test)
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
    precision = tp / (tp +fp)
    recall = tp / (tp + fn)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    print("Model: {}".format(name))
    print("precision = {:.2%}".format(precision))
    print("recall = {:.2%}".format(recall))
    print('accuracy = {:.2%}, score = {:.2%}'.format(accuracy,score))

# %%
user_df = pd.read_csv('Data/Donations_File.csv', parse_dates=['Date'])

# %%
user_df.drop(columns=['Donation ID','User ID','Givz Everywehre?','To Charity','Advised Charity',
                     'Unnamed: 10','Recurring Status','Advised Charity EIN','To Charity EIN'],inplace=True)

# %%
user_df['Event?'] = user_df['Event?'].apply(lambda x: False if math.isnan(x) else True)

# %%
# Drop Negative Tip Amounts
user_df = user_df[user_df.Tip >= 0]

# %%
#Calculate Proportion of Donations that Include Tip
tip_df = user_df[user_df.Tip > 0]

user_tip_proportion = (tip_df.shape[0])/(user_df.shape[0])

# %%
user_df['Tip'] = user_df['Tip'].apply(lambda x: False if x == 0.0 else True)

# %%
# Number to Beat!
user_tip_proportion
# Out:
# 0.10453648915187377

# %%
#user_df['Date'] = pd.to_datetime(user_df['Date'])
user_df['Year'] = user_df['Date'].apply(lambda x: x.year)
user_df['Month'] = user_df['Date'].apply(lambda x: x.month)
user_df['Day'] = user_df['Date'].apply(lambda x: x.day)
user_df['Hour'] = user_df['Date'].apply(lambda x: x.hour)
user_df['Minute'] = user_df['Date'].apply(lambda x: x.minute)

# %%
#user_df['Advised Charity EIN'] = user_df['Advised Charity EIN'].apply(lambda x: int(x.replace(',', '')))

# %%
user_df['Message to Charity2'] = user_df['Message to Charity2'].apply(lambda x: True if type(x) == str else False)
user_df['Message to Charity1'] = user_df['Message to Charity1'].apply(lambda x: True if type(x) == str else False)
user_df['Message'] = (user_df['Message to Charity2'] == True) | (user_df['Message to Charity1']==True)

# %%
user_df.drop(columns=['Date','Message to Charity1','Message to Charity2'],inplace=True)

# %%
user_df.head(100)
# Out:
#      Amount  In Honor Of?  Event?  Cover fee?    Tip  Year  Month  Day  Hour  \
# 0     25.00         False   False       False  False  2019      9   11     3
# 1     20.00         False   False       False  False  2019      9   10    22
# 2     21.00         False   False       False  False  2019      9   10    22
# 3    140.00         False   False       False  False  2019      9   10    22
# 4      1.00         False   False       False  False  2019      9   10    16
# 5      5.00         False   False       False   True  2019      9   10    10
# 6   1400.00         False   False       False  False  2019      9   10     9
# 7      1.00         False   False       False  False  2019      9    9    17
# 8     12.00         False   False       False  False  2019      9    9    16
# 9    117.00         False   False       False  False  2019      9    9    12
# 10   117.00         False   False       False  False  2019      9    9    11
# 11   117.00         False   False       False  False  2019      9    8    12
# 12     0.50         False   False       False  False  2019      9    5    22
# 13    50.00         False   False       False   True  2019      9    5     0
# 14    54.00         False   False       False   True  2019      9    3    20
# 15   100.00          True   False       False   True  2019      9    3     8
# 16    10.00         False   False       False   True  2019      9    2    23
# 17    10.00         False   False       False   True  2019      9    2    23
# 18    10.00         False   False       False  False  2019      9    2    23
# 19     5.00         False   False       False  False  2019      9    2    22
# 20     5.00         False   False       False  False  2019      9    2    22
# 21     5.00         False   False       False  False  2019      9    2    22
# 22     5.00         False   False       False  False  2019      9    2    22
# 23    50.00         False   False       False   True  2019      8   29     8
# 24    25.00         False   False       False  False  2019      8   26    22
# 25    50.00         False   False       False  False  2019      8   26    22
# 26     5.00         False   False        True  False  2019      8   23    22
# 27   100.00         False   False       False   True  2019      8   23     7
# 28    10.00         False   False       False   True  2019      8   18    20
# 29    10.00         False   False       False   True  2019      8   18    20
# ..      ...           ...     ...         ...    ...   ...    ...  ...   ...
# 70     5.00         False   False       False  False  2019      8    2    22
# 71     5.00         False   False       False  False  2019      8    2    22
# 72     0.50         False   False       False  False  2019      8    1    21
# 73     0.50         False    True       False  False  2019      8    1    11
# 74     0.50         False   False       False  False  2019      7   31    13
# 75     0.50         False   False       False  False  2019      7   31    13
# 76     0.50         False   False       False  False  2019      7   31    13
# 77    35.00          True   False       False  False  2019      7   30    10
# 78   313.64         False    True       False  False  2019      7   29    20
# 79     0.50         False   False       False  False  2019      7   29    17
# 80     0.50         False   False       False  False  2019      7   29    17
# 81     1.00         False   False       False  False  2019      7   29    15
# 82     0.50         False   False       False  False  2019      7   29    10
# 83     5.00         False   False       False   True  2019      7   27    17
# 84    25.00         False   False       False  False  2019      7   26    22
# 85    50.00         False   False       False  False  2019      7   26    22
# 86     0.50         False   False       False  False  2019      7   25     9
# 87   313.64         False    True       False  False  2019      7   24    21
# 88   200.00         False   False       False   True  2019      7   24    20
# 89     2.22         False   False       False  False  2019      7   24    14
# 90   313.64         False    True       False  False  2019      7   24    11
# 91     5.00         False   False        True  False  2019      7   23    22
# 92     5.00         False   False       False  False  2019      7   23    16
# 93   100.00         False   False        True  False  2019      7   23    11
# 94   520.64         False    True       False  False  2019      7   23    10
# 95     5.00         False   False       False   True  2019      7   22    15
# 96     5.00         False   False       False   True  2019      7   22    11
# 97   100.00          True   False       False  False  2019      7   21    10
# 98   260.32         False    True       False  False  2019      7   19    21
# 99   570.64         False    True       False  False  2019      7   18    15
#
#     Minute  Message
# 0       17    False
# 1       55    False
# 2       55    False
# 3       29    False
# 4       52    False
# 5       13    False
# 6       49    False
# 7       17    False
# 8       17    False
# 9        3    False
# 10       5    False
# 11      48    False
# 12      55    False
# 13      20     True
# 14      46    False
# 15      23    False
# 16      31    False
# 17      30    False
# 18      29    False
# 19      55    False
# 20      55    False
# 21      55    False
# 22      55    False
# 23      55    False
# 24      55    False
# 25      55    False
# 26      55    False
# 27      22    False
# 28      58    False
# 29      51    False
# ..     ...      ...
# 70      55    False
# 71      55    False
# 72       7    False
# 73       6    False
# 74      30    False
# 75       3    False
# 76       3    False
# 77      55    False
# 78      30    False
# 79      51    False
# 80      50    False
# 81      34    False
# 82      27    False
# 83      40    False
# 84      55    False
# 85      55    False
# 86      37    False
# 87      22    False
# 88      43    False
# 89      54    False
# 90      17    False
# 91      55    False
# 92      35    False
# 93      57     True
# 94      26    False
# 95       7    False
# 96      29    False
# 97       3    False
# 98      36    False
# 99      54    False
#
# [100 rows x 11 columns]

# %%
# df['month'] = df['start_date'].dt.month
# df['year'] = df['start_date'].dt.year
# df['day_of_week'] = df['start_date'].dt.dayofweek
# df['hour'] = df['start_date'].dt.hour
# df.head()

# %%
y = user_df['Tip']
X = user_df.drop(columns=['Tip'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# # Random Forest

# %%
forest = RandomForestClassifier(oob_score=True,n_estimators=300)
forest.fit(X_train,y_train)
score_matrix(forest)
# Out:
# Model: RandomForestClassifier
# precision = 67.35%
# recall = 50.00%
# accuracy = 92.27%, score = 92.27%

# %% [markdown]
# # Logistic Regression

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
score_matrix(log_reg)
# Out:
# Model: LogisticRegression
# precision = 41.18%
# recall = 10.61%
# accuracy = 89.12%, score = 89.12%
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
